# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/RiyadhVillasAqar.csv")
# Out:
# <ipython-input-4-aef5f97272a9>:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/RiyadhVillasAqar.csv")

# %%
df
# Out:
#        Unnamed: 0         front  rooms lounges bathrooms  streetWidth  stairs  \
# 0               0         شرقية      5     4.0        5+         20.0     1.0
# 1               1         غربية      4     3.0        5+         20.0     1.0
# 2               2  جنوبية شرقية      7     2.0        5+         15.0     1.0
# 3               3         غربية      7     3.0        5+         15.0     1.0
# 4               4        شمالية      4     2.0         4         25.0     1.0
# ...           ...           ...    ...     ...       ...          ...     ...
# 46821       51840        جنوبية      5       2        5+         20.0     1.0
# 46822       51841         غربية      7       2        5+         12.0     1.0
# 46823       51842         غربية      5       3        5+         20.0     0.0
# 46824       51843  جنوبية غربية      1     NaN         1         15.0     0.0
# 46825       51844        شمالية      6       2        5+         15.0     1.0
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# front               0
# rooms               0
# lounges          1118
# bathrooms           0
# streetWidth       190
# stairs              0
# propertyAge         0
# driverRoom          0
# tent                0
# patio               0
# kitchen             0
# outdoorRoom         0
# garage              0
# duplex              0
# space               0
# apartments          0
# maidRoom            0
# elevator            0
# furnihsed           0
# pool                0
# basement            0
# neighbourhood       0
# location            0
# price               2
# square price        2
# dtype: int64

# %%
df['new_lounges'] = df['lounges'].apply(lambda x: 0 if pd.notnull(x) else 1)

# %%
df
# Out:
#        Unnamed: 0         front  rooms lounges bathrooms  streetWidth  stairs  \
# 0               0         شرقية      5     4.0        5+         20.0     1.0
# 1               1         غربية      4     3.0        5+         20.0     1.0
# 2               2  جنوبية شرقية      7     2.0        5+         15.0     1.0
# 3               3         غربية      7     3.0        5+         15.0     1.0
# 4               4        شمالية      4     2.0         4         25.0     1.0
# ...           ...           ...    ...     ...       ...          ...     ...
# 46821       51840        جنوبية      5       2        5+         20.0     1.0
# 46822       51841         غربية      7       2        5+         12.0     1.0
# 46823       51842         غربية      5       3        5+         20.0     0.0
# 46824       51843  جنوبية غربية      1     NaN         1         15.0     0.0
# 46825       51844        شمالية      6       2        5+         15.0     1.0
#
# ...

# %%
df2 = df.dropna(subset=['lounges'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45708 entries, 0 to 46825
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     45708 non-null  int64
#  1   front          45708 non-null  object
#  2   rooms          45708 non-null  int64
#  3   lounges        45708 non-null  object
#  4   bathrooms      45708 non-null  object
#  5   streetWidth    45536 non-null  float64
#  6   stairs         45708 non-null  float64
#  7   propertyAge    45708 non-null  float64
#  8   driverRoom     45708 non-null  float64
#  9   tent           45708 non-null  float64
#  10  patio          45708 non-null  float64
#  11  kitchen        45708 non-null  float64
#  12  outdoorRoom    45708 non-null  float64
#  13  garage         45708 non-null  float64
#  14  duplex         45708 non-null  float64
#  15  space          45708 non-null  int64
#  16  apartments     45708 non-null  object
# ...

# %%
df2
# Out:
#        Unnamed: 0         front  rooms lounges bathrooms  streetWidth  stairs  \
# 0               0         شرقية      5     4.0        5+         20.0     1.0
# 1               1         غربية      4     3.0        5+         20.0     1.0
# 2               2  جنوبية شرقية      7     2.0        5+         15.0     1.0
# 3               3         غربية      7     3.0        5+         15.0     1.0
# 4               4        شمالية      4     2.0         4         25.0     1.0
# ...           ...           ...    ...     ...       ...          ...     ...
# 46820       51839        جنوبية      1       2         3         15.0     1.0
# 46821       51840        جنوبية      5       2        5+         20.0     1.0
# 46822       51841         غربية      7       2        5+         12.0     1.0
# 46823       51842         غربية      5       3        5+         20.0     0.0
# 46825       51844        شمالية      6       2        5+         15.0     1.0
#
# ...

# %%
df3 = df[df['lounges'].isna()]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1118 entries, 79 to 46824
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1118 non-null   int64
#  1   front          1118 non-null   object
#  2   rooms          1118 non-null   int64
#  3   lounges        0 non-null      object
#  4   bathrooms      1118 non-null   object
#  5   streetWidth    1100 non-null   float64
#  6   stairs         1118 non-null   float64
#  7   propertyAge    1118 non-null   float64
#  8   driverRoom     1118 non-null   float64
#  9   tent           1118 non-null   float64
#  10  patio          1118 non-null   float64
#  11  kitchen        1118 non-null   float64
#  12  outdoorRoom    1118 non-null   float64
#  13  garage         1118 non-null   float64
#  14  duplex         1118 non-null   float64
#  15  space          1118 non-null   int64
#  16  apartments     1118 non-null   object
# ...

# %%
df3
# Out:
#        Unnamed: 0         front  rooms lounges bathrooms  streetWidth  stairs  \
# 79             88         غربية      5     NaN         4         20.0     0.0
# 97            109  جنوبية شرقية      4     NaN         4         35.0     0.0
# 119           135         شرقية      4     NaN         3         20.0     1.0
# 125           142        شمالية      4     NaN         2         15.0     0.0
# 128           145         شرقية      4     NaN         3         20.0     1.0
# ...           ...           ...    ...     ...       ...          ...     ...
# 46590       51588        جنوبية      5     NaN        5+         15.0     0.0
# 46669       51675  شمالية شرقية      7     NaN        5+         20.0     0.0
# 46749       51764         شرقية      4     NaN        5+         40.0     0.0
# 46814       51833        جنوبية      4     NaN         3         15.0     0.0
# 46824       51843  جنوبية غربية      1     NaN         1         15.0     0.0
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46821    False
# 46822     True
# 46823    False
# 46824    False
# 46825     True
# Length: 46826, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df['front'].unique()
# Out:
# array(['شرقية', 'غربية', 'جنوبية شرقية', 'شمالية', 'شمالية شرقية',
#        'جنوبية', 'جنوبية غربية', 'شمالية غربية', 'ثلاث شوارع',
#        'أربع شوارع'], dtype=object)

# %%
df['front']=df['front'].replace({'شمالية': 1, 'جنوبية':2,'شرقية':3,'غربية':4,'شمالية شرقية' : 13, 'شمالية غربية':14,'جنوبية غربية':24,'جنوبية شرقية':23,'جنوبية غربية':24,'ثلاث شوارع':123,'أربع شوارع':1234})

# %%
k= sns.countplot(df,x="front")
k.bar_label(k.containers[0])
plt.title("front")
plt.show()

# %%
df['lounges'].unique()
# Out:
# array(['4.0', '3.0', '2.0', '5.0', '1.0', nan, '3', '2', '1', '5', '4',
#        '7+'], dtype=object)

# %%
df['lounges']=df['lounges'].replace('Nan','0')

# %%
df['lounges']=df['lounges'].replace('7+','7')

# %%
k1= sns.countplot(df,x="lounges")
k1.bar_label(k1.containers[0])
plt.title("lounges")
plt.show()

# %%
df.isna().sum()
# Out:
# front              0
# rooms              0
# lounges          872
# bathrooms          0
# streetWidth      156
# stairs             0
# propertyAge        0
# driverRoom         0
# tent               0
# patio              0
# kitchen            0
# outdoorRoom        0
# garage             0
# duplex             0
# space              0
# apartments         0
# maidRoom           0
# elevator           0
# furnihsed          0
# pool               0
# basement           0
# neighbourhood      0
# location           0
# price              2
# square price       2
# new_lounges        0
# dtype: int64

# %%
df.dtypes
# Out:
# front              int64
# rooms              int64
# lounges           object
# bathrooms         object
# streetWidth      float64
# stairs           float64
# propertyAge      float64
# driverRoom       float64
# tent             float64
# patio            float64
# kitchen          float64
# outdoorRoom      float64
# garage           float64
# duplex           float64
# space              int64
# apartments        object
# maidRoom         float64
# elevator         float64
# furnihsed        float64
# pool             float64
# basement         float64
# neighbourhood     object
# location          object
# price            float64
# square price     float64
# new_lounges        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39368 entries, 0 to 46824
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   front          39368 non-null  int64
#  1   rooms          39368 non-null  int64
#  2   lounges        38496 non-null  object
#  3   bathrooms      39368 non-null  object
#  4   streetWidth    39212 non-null  float64
#  5   stairs         39368 non-null  float64
#  6   propertyAge    39368 non-null  float64
#  7   driverRoom     39368 non-null  float64
#  8   tent           39368 non-null  float64
#  9   patio          39368 non-null  float64
#  10  kitchen        39368 non-null  float64
#  11  outdoorRoom    39368 non-null  float64
#  12  garage         39368 non-null  float64
#  13  duplex         39368 non-null  float64
#  14  space          39368 non-null  int64
#  15  apartments     39368 non-null  object
#  16  maidRoom       39368 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['front', 'rooms', 'lounges', 'bathrooms', 'streetWidth', 'stairs',
#        'propertyAge', 'driverRoom', 'tent', 'patio', 'kitchen', 'outdoorRoom',
#        'garage', 'duplex', 'space', 'apartments', 'maidRoom', 'elevator',
#        'furnihsed', 'pool', 'basement', 'neighbourhood', 'location', 'price',
#        'square price', 'new_lounges'],
#       dtype='object')

# %%
df['bathrooms'].unique()
# Out:
# array(['5+', '4', '3', '2', '1'], dtype=object)

# %%
df['bathrooms'].value_counts()
# Out:
# 5+    27146
# 4      7436
# 3      3509
# 2      1010
# 1       267
# Name: bathrooms, dtype: int64
